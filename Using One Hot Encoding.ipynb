# %% [markdown]
# ONE-HOT ENCODING

# %% [markdown]
# import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sea

# %% [markdown]
# DATA SETS

# %%
dataset = pd.read_csv('new_churn_data.csv')

# %% [markdown]
# EDA

# %%
dataset.head()
# Out:
#     user  churn   age housing  deposits  withdrawal  purchases_partners  \
# 0  55409      0  37.0      na         0           0                   0
# 1  23547      0  28.0       R         0           0                   1
# 2  58313      0  35.0       R        47           2                  86
# 3   8095      0  26.0       R        26           3                  38
# 4  61353      1  27.0      na         0           0                   2
#
#    purchases  cc_taken  cc_recommended  ...  payment_type  waiting_4_loan  \
# 0          0         0               0  ...     Bi-Weekly               0
# 1          0         0              96  ...        Weekly               0
# 2         47         0             285  ...  Semi-Monthly               0
# 3         25         0              74  ...     Bi-Weekly               0
# 4          0         0               0  ...     Bi-Weekly               0
#
#    cancelled_loan  received_loan  rejected_loan  zodiac_sign  \
# 0               0              0              0          Leo
# 1               0              0              0          Leo
# 2               0              0              0    Capricorn
# 3               0              0              0    Capricorn
# 4               0              0              0        Aries
#
#    left_for_two_month_plus  left_for_one_month reward_rate  is_referred
# 0                        1                   0        0.00            0
# 1                        0                   0        1.47            1
# 2                        1                   0        2.17            0
# 3                        0                   0        1.10            1
# 4                        1                   0        0.03            0
#
# [5 rows x 28 columns]

# %%
dataset.describe()
# Out:
#                user         churn           age      deposits    withdrawal  \
# count  26996.000000  26996.000000  26996.000000  26996.000000  26996.000000
# mean   35418.535302      0.413913     32.219921      3.342051      0.307045
# std    20319.620354      0.492542      9.964838      9.131992      1.055488
# min        1.000000      0.000000     17.000000      0.000000      0.000000
# 25%    17808.750000      0.000000     25.000000      0.000000      0.000000
# 50%    35745.500000      0.000000     30.000000      0.000000      0.000000
# 75%    53236.750000      1.000000     37.000000      1.000000      0.000000
# max    69658.000000      1.000000     91.000000     65.000000     29.000000
#
#        purchases_partners     purchases      cc_taken  cc_recommended  \
# count        26996.000000  26996.000000  26996.000000    26996.000000
# mean            28.066677      3.273967      0.073789       92.639502
# std             42.221432      8.953651      0.437331       88.868773
# min              0.000000      0.000000      0.000000        0.000000
# 25%              0.000000      0.000000      0.000000       10.000000
# 50%              9.000000      0.000000      0.000000       65.000000
# 75%             43.000000      1.000000      0.000000      164.000000
# max           1067.000000     63.000000     29.000000      522.000000
#
#         cc_disliked  ...  android_user  registered_phones  waiting_4_loan  \
# count  26996.000000  ...  26996.000000       26996.000000    26996.000000
# mean       0.050637  ...      0.587235           0.420988        0.001296
# std        0.871431  ...      0.492340           0.912884        0.035984
# min        0.000000  ...      0.000000           0.000000        0.000000
# 25%        0.000000  ...      0.000000           0.000000        0.000000
# 50%        0.000000  ...      1.000000           0.000000        0.000000
# 75%        0.000000  ...      1.000000           0.000000        0.000000
# max       65.000000  ...      1.000000           5.000000        1.000000
#
#        cancelled_loan  received_loan  rejected_loan  left_for_two_month_plus  \
# count    26996.000000   26996.000000   26996.000000              26996.00000
# mean         0.018818       0.018188       0.004890                  0.17347
# std          0.135883       0.133633       0.069756                  0.37866
# min          0.000000       0.000000       0.000000                  0.00000
# 25%          0.000000       0.000000       0.000000                  0.00000
# 50%          0.000000       0.000000       0.000000                  0.00000
# 75%          0.000000       0.000000       0.000000                  0.00000
# max          1.000000       1.000000       1.000000                  1.00000
#
#        left_for_one_month   reward_rate   is_referred
# count        26996.000000  26996.000000  26996.000000
# mean             0.018077      0.907819      0.318010
# std              0.133232      0.751991      0.465712
# min              0.000000      0.000000      0.000000
# 25%              0.000000      0.200000      0.000000
# 50%              0.000000      0.780000      0.000000
# 75%              0.000000      1.530000      1.000000
# max              1.000000      4.000000      1.000000
#
# [8 rows x 25 columns]

# %%
user_identifier = dataset['user']
dataset = dataset.drop(columns = ['user'])

# %%
dataset.housing.value_counts()
# Out:
# na    13856
# R     10969
# O      2171
# Name: housing, dtype: int64

# %%
dataset = pd.get_dummies(dataset)
dataset.columns
# Out:
# Index(['churn', 'age', 'deposits', 'withdrawal', 'purchases_partners',
#        'purchases', 'cc_taken', 'cc_recommended', 'cc_disliked', 'cc_liked',
#        'cc_application_begin', 'app_downloaded', 'web_user', 'ios_user',
#        'android_user', 'registered_phones', 'waiting_4_loan', 'cancelled_loan',
#        'received_loan', 'rejected_loan', 'left_for_two_month_plus',
#        'left_for_one_month', 'reward_rate', 'is_referred', 'housing_O',
#        'housing_R', 'housing_na', 'payment_type_Bi-Weekly',
#        'payment_type_Monthly', 'payment_type_Semi-Monthly',
#        'payment_type_Weekly', 'payment_type_na', 'zodiac_sign_Aquarius',
#        'zodiac_sign_Aries', 'zodiac_sign_Cancer', 'zodiac_sign_Capricorn',
#        'zodiac_sign_Gemini', 'zodiac_sign_Leo', 'zodiac_sign_Libra',
#        'zodiac_sign_Pisces', 'zodiac_sign_Sagittarius', 'zodiac_sign_Scorpio',
#        'zodiac_sign_Taurus', 'zodiac_sign_Virgo', 'zodiac_sign_na'],
#       dtype='object')

# %%
dataset = dataset.drop(columns = ['housing_na', 'zodiac_sign_na','payment_type_na'])

# %%
from sklearn.model_selection import train_test_split
X_train , X_test, y_train , y_test = train_test_split(dataset.drop(columns='churn'),dataset['churn'],test_size=0.2 , random_state= 0)

# %%
y_train.value_counts()

pos_index = y_train[y_train.values==1].index
neg_index = y_train[y_train.values==0].index

if len(pos_index)>len(neg_index):
    higher = pos_index
    lower =  neg_index

else:
    lower = pos_index
    higher =  neg_index

import random
random.seed(0)
higher = np.random.choice(higher,size = len(lower))
lower = np.asarray(lower)
new_indexes = np.concatenate((lower,higher))

X_train = X_train.loc[new_indexes, ]
y_train = y_train[new_indexes]

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train2 = pd.DataFrame(sc_X.fit_transform(X_train))
X_test2 = pd.DataFrame(sc_X.transform(X_test))
X_train2.columns = X_train.columns.values
X_test2.columns = X_test.columns.values
X_train2.index = X_train.index.values
X_test2.index = X_test.index.values
X_train = X_train2
X_test = X_test2

# %% [markdown]
# Model Building

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state=0)
classifier.fit(X_train, y_train)


y_pred = classifier.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score , f1_score , precision_score , recall_score
cm = confusion_matrix(y_test, y_pred)

accuracy_score(y_test, y_pred)
# Out:
# 0.6183333333333333

# %%
precision_score(y_test, y_pred)
# Out:
# 0.5274516026658204

# %%
recall_score(y_test, y_pred)
# Out:
# 0.7439570277529096

# %%
f1_score(y_test, y_pred)
# Out:
# 0.6172701949860724

# %%
df_cm = pd.DataFrame(cm , index=(0,1),columns=(0,1))
plt.figure(figsize=(10,7))
sea.set(font_scale =1.4)
sea.heatmap(df_cm ,annot=True , fmt='g')
print("Test Data Accuracy: %0.4f" % accuracy_score(y_test, y_pred)   )
# Out:
# Test Data Accuracy: 0.6183

# %%
from sklearn.model_selection import cross_val_score
acc = cross_val_score(estimator=classifier, X = X_train , y = y_train , cv=10)
acc
# Out:
# array([0.64653244, 0.65604027, 0.64876957, 0.64205817, 0.62751678,
#        0.65995526, 0.63758389, 0.64988814, 0.64653244, 0.651566  ])

# %%
acc.mean()
# Out:
# 0.6466442953020135

# %%
pd.concat([pd.DataFrame(X_train.columns,columns=["features"]),
            pd.DataFrame(np.transpose(classifier.coef_),columns=["coef"])] ,axis =1 )
# Out:
#                      features      coef
# 0                         age -0.176361
# 1                    deposits  0.233293
# 2                  withdrawal  0.047526
# 3          purchases_partners -0.731186
# 4                   purchases -0.375315
# 5                    cc_taken  0.086694
# 6              cc_recommended  0.097816
# 7                 cc_disliked -0.020940
# 8                    cc_liked  0.001458
# 9        cc_application_begin  0.028870
# 10             app_downloaded -0.052457
# 11                   web_user  0.153075
# 12                   ios_user  0.180814
# 13               android_user  0.120128
# 14          registered_phones  0.083541
# 15             waiting_4_loan -0.041332
# 16             cancelled_loan  0.091452
# 17              received_loan  0.103081
# 18              rejected_loan  0.118698
# 19    left_for_two_month_plus  0.057768
# 20         left_for_one_month  0.037181
# 21                reward_rate -0.241276
# 22                is_referred  0.017327
# 23                  housing_O -0.046161
# 24                  housing_R  0.031259
# 25     payment_type_Bi-Weekly -0.095820
# 26       payment_type_Monthly -0.015701
# 27  payment_type_Semi-Monthly -0.041861
# 28        payment_type_Weekly  0.010157
# 29       zodiac_sign_Aquarius -0.032796
# 30          zodiac_sign_Aries -0.003775
# 31         zodiac_sign_Cancer  0.024740
# 32      zodiac_sign_Capricorn  0.014642
# 33         zodiac_sign_Gemini -0.032403
# 34            zodiac_sign_Leo -0.004578
# 35          zodiac_sign_Libra -0.032426
# 36         zodiac_sign_Pisces  0.018094
# 37    zodiac_sign_Sagittarius -0.021550
# 38        zodiac_sign_Scorpio -0.021644
# 39         zodiac_sign_Taurus -0.013183
# 40          zodiac_sign_Virgo  0.011693

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression


classifier = LogisticRegression()

# %%
rfe = RFE(classifier)
rfe = rfe.fit(X_train, y_train)
print(rfe.support_)
print(rfe.ranking_)
X_train.columns[rfe.support_]
# Out:
# [ True  True  True  True  True  True  True False False False  True  True
#   True  True  True False  True  True  True  True False  True False  True
#  False  True False  True False False False False False False False False
#  False False False False False]
# [ 1  1  1  1  1  1  1 12 22  8  1  1  1  1  1  2  1  1  1  1  3  1 15  1
#   4  1 14  1 19  5 21  9 13  6 20  7 10 17 16 18 11]
# Index(['age', 'deposits', 'withdrawal', 'purchases_partners', 'purchases',
#        'cc_taken', 'cc_recommended', 'app_downloaded', 'web_user', 'ios_user',
#        'android_user', 'registered_phones', 'cancelled_loan', 'received_loan',
#        'rejected_loan', 'left_for_two_month_plus', 'reward_rate', 'housing_O',
#        'payment_type_Bi-Weekly', 'payment_type_Semi-Monthly'],
#       dtype='object')

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state=0)
classifier.fit(X_train[X_train.columns[rfe.support_]], y_train)


y_pred = classifier.predict(X_test[X_train.columns[rfe.support_]])

from sklearn.metrics import confusion_matrix, accuracy_score , f1_score , precision_score , recall_score
cm = confusion_matrix(y_test, y_pred)

accuracy_score(y_test, y_pred)
# Out:
# 0.6118518518518519

# %%
precision_score(y_test, y_pred)
# Out:
# 0.5218769816106531

# %%
recall_score(y_test, y_pred)
# Out:
# 0.7367949865711728

# %%
f1_score(y_test, y_pred)
# Out:
# 0.6109873793615442

# %%
pd.concat([pd.DataFrame(X_train.columns[rfe.support_],columns=["features"]),
            pd.DataFrame(np.transpose(classifier.coef_),columns=["coef"])] ,axis =1 )
# Out:
#                      features      coef
# 0                         age -0.178802
# 1                    deposits  0.262390
# 2                  withdrawal  0.051515
# 3          purchases_partners -0.728620
# 4                   purchases -0.393528
# 5                    cc_taken  0.092284
# 6              cc_recommended  0.125563
# 7              app_downloaded -0.048174
# 8                    web_user  0.158032
# 9                    ios_user  0.182654
# 10               android_user  0.118496
# 11          registered_phones  0.086603
# 12             cancelled_loan  0.089783
# 13              received_loan  0.102253
# 14              rejected_loan  0.117657
# 15    left_for_two_month_plus  0.059573
# 16                reward_rate -0.240503
# 17                  housing_O -0.054110
# 18     payment_type_Bi-Weekly -0.095939
# 19  payment_type_Semi-Monthly -0.042850

# %%
final_results = pd.concat([y_test,user_identifier],axis =1).dropna()
final_results['predicted_churn'] = y_pred
final_results = final_results[['user', 'churn', 'predicted_churn']].reset_index(drop=True)
final_results
# Out:
#        user  churn  predicted_churn
# 0     53016    1.0                1
# 1     54963    0.0                0
# 2     10511    0.0                0
# 3     64269    0.0                1
# 4     30978    0.0                0
# ...     ...    ...              ...
# 5395  50513    1.0                1
# 5396  42775    0.0                1
# 5397  15284    1.0                1
# 5398  10432    1.0                1
# 5399  55716    0.0                1
#
# [5400 rows x 3 columns]
